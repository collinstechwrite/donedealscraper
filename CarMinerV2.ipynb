# %%
from openpyxl import Workbook, load_workbook



    
    
import xlsxwriter
workbook = xlsxwriter.Workbook('analysis.xlsx')
worksheet = workbook.add_worksheet()
workbook.close()


    
    

Row_Incrementer = 2

def spreadsheet_titles():
    Row_Incrementer = 1
    workbook = load_workbook(filename="analysis.xlsx")
    sheet = workbook.active

    sheet["A" + str(Row_Incrementer)] = "TITLE"
    sheet["B" + str(Row_Incrementer)] = "URL"
    sheet["C" + str(Row_Incrementer)] = "Location"
    sheet["D" + str(Row_Incrementer)] = "Price"
    sheet["E" + str(Row_Incrementer)] = "Make"
    sheet["F" + str(Row_Incrementer)] = "Model"
    sheet["G" + str(Row_Incrementer)] = "Year"
    sheet["H" + str(Row_Incrementer)] = "Fuel Type"
    sheet["I" + str(Row_Incrementer)] = "Body Type"
    sheet["J" + str(Row_Incrementer)] = "Engine Size (Litres)"
    sheet["K" + str(Row_Incrementer)] = "NCT Expiry"
    sheet["L" + str(Row_Incrementer)] = "Country of Registration"
    sheet["M" + str(Row_Incrementer)] = "Doors"
    sheet["N" + str(Row_Incrementer)] = "Mileage"
    sheet["O" + str(Row_Incrementer)] = "Transmission"
    sheet["P" + str(Row_Incrementer)] = "Seats"
    sheet["Q" + str(Row_Incrementer)] = "Road Tax"
    sheet["R" + str(Row_Incrementer)] = "Previous Owners"
    sheet["S" + str(Row_Incrementer)] = "Colour"
    sheet["T" + str(Row_Incrementer)] = "TOWN"
    sheet["U" + str(Row_Incrementer)] = "SELLER"
    sheet["V" + str(Row_Incrementer)] = "Dealer"

    workbook.save(filename="analysis.xlsx")   
    
        
    
def row_increment(Title,
                  URL,
                  Location,
                  Price,
                  Make,
                  Model,
                  Year,
                  FuelType,
                  BodyType,
                  EngineSize,
                  NCTExpiry,
                  Country,
                  Doors,
                  Mileage,
                  Transmission,
                  Seats,
                  RoadTax,
                  Owners,
                  Colour,
                  TOWN,
                  SELLER,
                  Dealer):

    global Row_Incrementer
    Row_Incrementer += 1


    workbook = load_workbook(filename="analysis.xlsx")
    sheet = workbook.active

    sheet["A" + str(Row_Incrementer)] = Title
    sheet["B" + str(Row_Incrementer)] = URL
    sheet["C" + str(Row_Incrementer)] = Location
    sheet["D" + str(Row_Incrementer)] = Price    
    sheet["E" + str(Row_Incrementer)] = Make
    sheet["F" + str(Row_Incrementer)] = Model
    sheet["G" + str(Row_Incrementer)] = Year
    sheet["H" + str(Row_Incrementer)] = FuelType
    sheet["I" + str(Row_Incrementer)] = BodyType
    sheet["J" + str(Row_Incrementer)] = EngineSize
    sheet["K" + str(Row_Incrementer)] = NCTExpiry
    sheet["L" + str(Row_Incrementer)] = Country
    sheet["M" + str(Row_Incrementer)] = Doors
    sheet["N" + str(Row_Incrementer)] = Mileage
    sheet["O" + str(Row_Incrementer)] = Transmission
    sheet["P" + str(Row_Incrementer)] = Seats
    sheet["Q" + str(Row_Incrementer)] = RoadTax
    sheet["R" + str(Row_Incrementer)] = Owners
    sheet["S" + str(Row_Incrementer)] = Colour
    sheet["T" + str(Row_Incrementer)] = TOWN
    sheet["U" + str(Row_Incrementer)] = SELLER
    sheet["V" + str(Row_Incrementer)] = Dealer # originally E

    
    
    
    workbook.save(filename="analysis.xlsx")    
    
    
    
spreadsheet_titles()


# importing re module
import requests
import re

count = 28


def get_LOCATION_url(url):
    
    try:

        tag5 = 'content="For Sale in '
        tag6 = ':'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""
    
"""------------------------------------------------------------------"""
    
def get_Make_url(url):
    
    try:

        tag5 = '"name":"make","value":"'
        tag6 = '","displayName":"Make / Model"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
    
def get_Model_url(url):
    
    try:


        tag5 = '{"name":"model","value":"'
        tag6 = '","displayName":"Model"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""


def get_Year_url(url):
    
    try:


        tag5 = '{"name":"year","value":"'
        tag6 = '","displayName":"Year"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_FuelType_url(url):
    
    try:

        tag5 = '{"name":"fuelType","value":"'
        tag6 = '","displayName":"Fuel Type"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_BodyType_url(url):
    
    try:

        tag5 = '{"name":"bodyType","value":"'
        tag6 = '","displayName":"Body Type"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""


def get_EngineSize_url(url):
    
    try:


        tag5 = '{"name":"engine","value":"'
        tag6 = '","displayName":"Engine Size (Litres)"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""


def get_NCTExpiry_url(url):
    
    try:


        tag5 = '{"name":"NCT","value":"'
        tag6 = '","displayName":"NCT Expiry"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""



def get_Country_url(url):
    
    try:

        tag5 = '{"name":"country","value":"'
        tag6 = '","displayName":"Country of Registration"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    

def get_Doors_url(url):
    
    try:


        tag5 = '{"name":"numDoors","value":"'
        tag6 = '","displayName":"Doors"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    

def get_Mileage_url(url):
    
    try:


        tag5 = '{"name":"mileage","value":"'
        tag6 = '","displayName":"Mileage"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_Transmission_url(url):
    
    try:


        tag5 = '{"name":"transmission","value":"'
        tag6 = '","displayName":"Transmission"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_Seats_url(url):
    
    try:


        tag5 = '{"name":"seats","value":"'
        tag6 = '","displayName":"Seats","badge":'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_RoadTax_url(url):
    
    try:


        tag5 = '{"name":"roadTax","value":"'
        tag6 = '","displayName":"Road Tax"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
    
def get_Owners_url(url):
    
    try:


        tag5 = 'name":"previousOwners","value":"'
        tag6 = '","displayName":"Previous Owners"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_Colour_url(url):
    
    try:


        tag5 = '{"name":"colour","value":"'
        tag6 = '","displayName":"Colour"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_TOWN_url(url):
    
    try:


        tag5 = '"countyTown":"'
        tag6 = '"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    
def get_SELLER_url(url):
    
    try:


        tag5 = '"publisherName":"'
        tag6 = '","publisherPhoneEnc"'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    
    except:
        return ""

    

"""------------------------------------------------------------------""" 
    
def get_Price_url(url):
    
    try:


        tag5 = '<meta property="product:price:amount" content="'
        tag6 = '" />'
        reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
        res4 = re.findall(reg_str3, url)[0]
        
        return res4
    except:
        return ""
     

        
def get_Dealer_url(url):    
        try:

            tag5 = '<p class="card__header-title" data-reactid="8">'
            tag6 = '</p><ul class="card__header-subinfo" data-reactid="9">'
            reg_str3 = "" + tag5 + "(.*?)" + tag6 + ""
            res4 = re.findall(reg_str3, url)[0]

            return res4
        
        except:
            
            return "SELLER NOT LISTED"

            
        
        
        
        

def findcars():
    global count
    r = requests.get('https://www.donedeal.ie/cars?make=Volkswagen;model:Golf,Passat,Polo,Tiguan,Jetta&start=' + str(count))
    #print(r.text) 
    test_str = str(r.text)

    # initializing string
    #test_str = '="916228031"><li class="card-item" id="cad-card-27283787" data-reactid="2"><a href="https://www.donedeal.ie/cars-for-sale/volkswagen-jetta-nct-tax-can-do-delivery-for-free/27283787?campaign=3" target="_self" class="card__link" data-reactid="3"><div class="card card--spotlight" data-reactid="4"><span class="card__tag" data-reactid="5">Spotlight</span><div class="card__media" data-reactid="6"><div class="card__photo" data-reactid="7"><img src="https://photos.donedeal.ie/ddimg/MzAyMzA0ZWNjYTZkYzIwMDUxNDdkMjQwZGE0NzEwODb2zr9sn0NrVSRF3w4tB6TFaHR0cDovL3MzLWV1LXdlc3QtMS5hbWF6b25hd3MuY29tL2RvbmVkZWFsLmllLXBob3Rvcy9waG90b18xNzI4MTI5ODl8fHx8fHw2MDB4NDUwfHx8fHw=.jpeg" title="Volkswagen Jetta NCT, TAX.Can do delivery for free" alt="Volkswagen Jetta , Petrol, 2014, Other" data-reactid="8"/></div><div class="card__media-info" data-reactid="9"><span class="card__media-count" data-reactid="10"><i class="icon icon-camera" data-reactid="11"></i><!-- react-text: 12 -->1 / 10<!-- /react-text --></span></div></div><div class="card__body" data-reactid="13"><div class="card__body-1-of-2" data-reactid="14"><p class="card__body-title" data-reactid="15">Volkswagen Jetta NCT, TAX.Can do delivery for free</p><ul class="card__adinfo card__adinfo--is-grid-only" data-reactid="16"><li data-reactid="17">Westmeath</li><li data-reactid="18">54 days</li></ul><ul class="card__body-keyinfo" data-reactid="19"><li data-reactid="20">2014</li><li data-reactid="21">1.2 Petrol</li><li data-reactid="22">135,708 km</li><li data-reactid="23">54 days</li><li data-reactid="24">Westmeath</li></ul><p class="card__body-section ng-cloak" data-ng-if="currentSection.containsSubsections" data-ng-click="search.searchBySection(&#x27;cars&#x27;, $event);" data-reactid="25"><!-- react-text: 26 -->in <!-- /react-text --><!-- react-text: 27 -->Cars<!-- /react-text --></p></div><div class="card__body-2-of-2" data-reactid="28"><div data-reactid="29"><div class="card__trust-list" data-reactid="30"><div class="card__greenlight" data-reactid="31"><img class="greenlight" src="https://assets.donedeal.ie/classifieds/images/motor/greenlight/greenlight-label.svg" data-reactid="32"/></div></div></div><div class="card__price--info" data-reactid="33"><div class="card__price--left-options" data-reactid="34"><div class="card__price-header" data-reactid="35"><div class="card__price-title" data-reactid="36">Price</div></div><p class="card__price" data-reactid="37"><span data-reactid="38"><span data-reactid="39">&#128;</span><!-- react-text: 40 -->7,800<!-- /react-text --></span></p></div></div><div class="card__actions" data-reactid="41"><i class="manual-false-page card-actions__save icon icon-save-heart" data-ng-click="userSaveAd($event,0)" data-reactid="42"></i></div></div></div></div></a></li><li class="card-item" id="cad-card-27765013" data-reactid="43"><a href="https://www.donedeal.ie/cars-for-sale/2018-182-volkswagen-tiguan-highline-2-0tdi-auto/27765013?campaign=3" target="_self" class="card__link" data-reactid="44"><div class="card__header card__header--border" data-reactid="45"><div class="card__header-thumb" data-reactid="46"><img src="https://photos.donedeal.ie/ddimg/MDkwODA4NDFhMWY4OTJmMDM5MWQxYTU4YjA4ZTBiMTDPJqb-yVaOWZS_AVKaFflkaHR0cDovL3MzLWV1LXdlc3QtMS5hbWF6b25hd3MuY29tL2RvbmVkZWFsLmllLXBob3Rvcy9kZWFsZXJfbG9nb18xMTQ5NHx8fHx8fDY0eDY0fHx8fHw=.jpeg" data-reactid="47"/></div><div class="card__header-details" data-reactid="48"><p class="card__header-title" data-reactid="49">MotorCorp</p><ul class="card__header-subinfo" data-reactid="50"><li data-reactid="51">Independent Dealer</li></ul></div></div><div class="card card--spotlight" data-reactid="52"><span class="card__tag" data-reactid="53">Spotlight</span><div class="card__media" data-reactid="54"><div class="card__photo" data-reactid="55"><img src="https://photos.donedeal.ie/ddimg/ZGI4OGMyYjk3YzMzNDAzNzVkNjY2NjNiNzJjZmY0NWN-G-oy6z7lJzINoYxF4b4yaHR0cDovL3MzLWV1LXdlc3QtMS5hbWF6b25hd3MuY29tL2RvbmVkZWFsLmllLXBob3Rvcy9waG90b18xNzY2MTIzMTN8fHx8fHw2MDB4NDUwfHx8fHw=.jpeg" title="2018 (182) Volkswagen Tiguan Highline 2.0TDi Auto" alt="Volkswagen Tiguan SUV, Diesel, 2018, Black" data-reactid="56"/></div><div class="card__media-info" data-reactid="57"><span class="card__media-count" data-reactid="58"><i class="icon icon-camera" data-reactid="59"></i><!-- react-text: 60 -->1 / 23<!-- /react-text --></span></div></div><div class="card__body" data-reactid="61"><div class="card__body-1-of-2" data-reactid="62"><p class="card__body-title" data-reactid="63">2018 (182) Volkswagen Tiguan Highline 2.0TDi Auto</p><ul class="card__adinfo card__adinfo--is-grid-only" data-reactid="64"><li data-reactid="65">Dublin</li><li data-reactid="66">5 days</li></ul><ul class="card__body-keyinfo" data-reactid="67"><li data-reactid="68">2018</li><li data-reactid="69">2.0 Diesel</li><li data-reactid="70">25,000 km</li><li data-reactid="71">5 days</li><li data-reactid="72">Dublin</li></ul><p class="card__body-section ng-cloak" data-ng-if="currentSection.containsSubsections" data-ng-click="search.searchBySection(&#x27;cars&#x27;, $event);" data-reactid="73"><!-- react-text: 74 -->in <!-- /react-text --><!-- react-text: 75 -->Cars<!-- /react-text --></p></div><div class="card__body-2-of-2" data-reactid="76"><div data-reactid="77"><ul class="card__benefit-list" data-reactid="78"><li class="card__merit--gold" data-reactid="79">Warranty</li><li class="card__merit" data-reactid="80">History Checked</li></ul></div><div class="card__price--info" data-reactid="81"><div class="card__price--left-options" data-reactid="82"><div class="card__price-header" data-reactid="83"><div class="card__price-title" data-reactid="84">Price</div></div><p class="card__price" data-reactid="85"><span data-reactid="86"><span data-reactid="87">&#128;</span><!-- react-text: 88 -->34,990<!-- /react-text --></span></p></div><div class="card__price--right-options" data-reactid="89"><div class="card__price-title" data-reactid="90">From</div><p class="card__price" data-reactid="91"><span data-reactid="92"><span data-reactid="93">&#128;</span><!-- react-text: 94 -->671<!-- /react-text --></span><span class="card__price--subtext" data-reactid="95">p/m</span></p></div></div><div class="card__actions" data-reactid="96"><i class="manual-false-page card-actions__save icon icon-save-heart" data-ng-click="userSaveAd($event,1)" data-reactid="97"></i></div></div></div></div></a></li><li class="card-item" id="cad-card-27783409" data-reactid="98"><a href="https://www.donedeal.ie/cars-for-sale/vw-polo-se-2015-1-ltr/27783409?campaign=3" target="_self" class="card__link" data-reactid="99"><div class="card__header card__header--border" data-reactid="100"><div class="card__header-thumb" data-'


    # initializing tag
    tag1 = 'g" title="'
    tag2 ='"'

    tag3 = '><a href="'
    tag4 = '"'




    # regex to extract required strings
    reg_str = "" + tag1 + "(.*?)" + tag2 + ""
    reg_str2 = "" + tag3 + "(.*?)" + tag4 + ""

    res = re.findall(reg_str, test_str)
    res2 = re.findall(reg_str2, test_str)

    res3 = []

    for i in res2:
        if 'cars-for-sale' in i:
            res3.append(i)


    # printing result
    for i,z in zip(res,res3):
        print(i)
        print(z)
        
        
        process_string = requests.get(z)
        processing_string = process_string.text

        Location = get_LOCATION_url(processing_string)
        Price = get_Price_url(processing_string)
        Make = get_Make_url(processing_string)
        Model = get_Model_url(processing_string)
        Year = get_Year_url(processing_string)
        FuelType = get_FuelType_url(processing_string)
        BodyType = get_BodyType_url(processing_string)
        EngineSize = get_EngineSize_url(processing_string)
        NCTExpiry = get_NCTExpiry_url(processing_string)
        Country = get_Country_url(processing_string)
        Doors = get_Doors_url(processing_string)
        Mileage = get_Mileage_url(processing_string)
        Transmission = get_Transmission_url(processing_string)
        Seats = get_Seats_url(processing_string)
        RoadTax = get_RoadTax_url(processing_string)
        Owners = get_Owners_url(processing_string)
        Colour = get_Colour_url(processing_string)
        TOWN = get_TOWN_url(processing_string)
        SELLER = get_SELLER_url(processing_string)
        Dealer = get_Dealer_url(processing_string)
        
        
        print(Location)
        print(Price)
        print(Dealer)
              
        row_increment(
            i,
            z,
            Location,
            Price,          
            Make,
            Model,
            Year,
            FuelType,
            BodyType,
            EngineSize,
            NCTExpiry,
            Country,
            Doors,
            Mileage,
            Transmission,
            Seats,
            RoadTax,
            Owners,
            Colour,
            TOWN,
            SELLER,
            Dealer)
        
        #spreadsheet_update()
        print("----------------------------------------------------------------------------------")
    
    
    
    count += 28
    
while count < 281:
    findcars()
    print('FINDING NEW BATCH', count)
# Out:
# Volkswagen Tiguan 122BHP Brand New IN Stock FOR I
# https://www.donedeal.ie/cars-for-sale/volkswagen-tiguan-122bhp-brand-new-in-stock-for-i/27880390?campaign=3
# Cork
# 34890.00
# Newmarket Motors Ltd
# ----------------------------------------------------------------------------------
# Volkswagen Polo Comfortline 1.0 80bhp Brand New I
# https://www.donedeal.ie/cars-for-sale/volkswagen-polo-comfortline-1-0-80bhp-brand-new-i/26757169?campaign=3
# Cork
# 22761.00
# Newmarket Motors Ltd
# ----------------------------------------------------------------------------------
# Volkswagen Polo Trendline 1.0 Petrol 5 Door IN St
# https://www.donedeal.ie/cars-for-sale/volkswagen-polo-trendline-1-0-petrol-5-door-in-st/26920589?campaign=3
# Cork
# 17950.00
# Newmarket Motors Ltd
# ----------------------------------------------------------------------------------
# Volkswagen Polo TLINE (181)
# https://www.donedeal.ie/cars-for-sale/volkswagen-polo-tline-181/27888177
# Dublin
# 13800.00
# ...
